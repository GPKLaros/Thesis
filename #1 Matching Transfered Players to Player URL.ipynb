# %%
import pandas as pd
import numpy as np
#2015
#Creating a dataframe with all transfers made in different competitions and merging them
transfers_eredivisie_2015 = pd.read_csv('Transfers2015/dutch_eredivisie_2015.csv')
transfers_english_championship_2015 = pd.read_csv('Transfers2015/english_championship_2015.csv')
transfers_english_premier_league_2015 = pd.read_csv('Transfers2015/english_premier_league_2015.csv')
transfers_french_ligue_1_2015 = pd.read_csv('Transfers2015/french_ligue_1_2015.csv')
transfers_german_bundesliga_1_2015 = pd.read_csv('Transfers2015/german_bundesliga_1_2015.csv')
transfers_italian_serie_a_2015 = pd.read_csv('Transfers2015/italian_serie_a_2015.csv')
transfers_portugese_liga_nos_2015 = pd.read_csv('Transfers2015/portugese_liga_nos_2015.csv')
transfers_spanish_primera_division_2015 = pd.read_csv('Transfers2015/spanish_primera_division_2015.csv')
all_transfers_2015 = pd.concat([transfers_eredivisie_2015, transfers_english_championship_2015, transfers_english_premier_league_2015,transfers_french_ligue_1_2015,transfers_german_bundesliga_1_2015,transfers_italian_serie_a_2015,transfers_portugese_liga_nos_2015,transfers_spanish_primera_division_2015]).sort_index().reset_index(drop=True)
#Dropping all NaN's in the fee_cleaned column
all_transfer_2015 = all_transfers_2015.dropna(subset = ["fee_cleaned"], inplace = True)
all_transfers_2015 = pd.concat([all_transfers_2015]).sort_index().reset_index(drop=True)
#Taking out all values of 0 in fee_cleaned as this are not real transfers (mostly loans of ended contracts)
for i in range(len(all_transfers_2015)):
    if all_transfers_2015['fee_cleaned'][i] <= 0.00:
        all_transfers_2015 = all_transfers_2015.drop(i)
all_transfers_2015 = pd.concat([all_transfers_2015]).sort_index().reset_index(drop=True)
for i in range(len(all_transfers_2015)):
    if all_transfers_2015['transfer_movement'][i] == 'out':
        all_transfers_2015 = all_transfers_2015.drop(i)
all_transfers_2015 = pd.concat([all_transfers_2015]).sort_index().reset_index(drop=True)

#2016
#Creating a dataframe with all transfers made in different competitions and merging them
transfers_eredivisie_2016 = pd.read_csv('Transfers2016/dutch_eredivisie_2016.csv')
transfers_english_championship_2016 = pd.read_csv('Transfers2016/english_championship_2016.csv')
transfers_english_premier_league_2016 = pd.read_csv('Transfers2016/english_premier_league_2016.csv')
transfers_french_ligue_1_2016 = pd.read_csv('Transfers2016/french_ligue_1_2016.csv')
transfers_german_bundesliga_1_2016 = pd.read_csv('Transfers2016/german_bundesliga_1_2016.csv')
transfers_italian_serie_a_2016 = pd.read_csv('Transfers2016/italian_serie_a_2016.csv')
transfers_portugese_liga_nos_2016 = pd.read_csv('Transfers2016/portugese_liga_nos_2016.csv')
transfers_spanish_primera_division_2016 = pd.read_csv('Transfers2016/spanish_primera_division_2016.csv')
all_transfers_2016 = pd.concat([transfers_eredivisie_2016, transfers_english_championship_2016, transfers_english_premier_league_2016,transfers_french_ligue_1_2016,transfers_german_bundesliga_1_2016,transfers_italian_serie_a_2016,transfers_portugese_liga_nos_2016,transfers_spanish_primera_division_2016]).sort_index().reset_index(drop=True)
#Dropping all NaN's in the fee_cleaned column
all_transfer_2016 = all_transfers_2016.dropna(subset = ["fee_cleaned"], inplace = True)
all_transfers_2016 = pd.concat([all_transfers_2016]).sort_index().reset_index(drop=True)
#Taking out all values of 0 in fee_cleaned as this are not real transfers (mostly loans of ended contracts)
for i in range(len(all_transfers_2016)):
    if all_transfers_2016['fee_cleaned'][i] <= 0.00:
        all_transfers_2016 = all_transfers_2016.drop(i)
all_transfers_2016 = pd.concat([all_transfers_2016]).sort_index().reset_index(drop=True)
for i in range(len(all_transfers_2016)):
    if all_transfers_2016['transfer_movement'][i] == 'out':
        all_transfers_2016 = all_transfers_2016.drop(i)
all_transfers_2016 = pd.concat([all_transfers_2016]).sort_index().reset_index(drop=True)

#2017
#Creating a dataframe with all transfers made in different competitions and merging them
transfers_eredivisie_2017 = pd.read_csv('Transfers2017/dutch_eredivisie_2017.csv')
transfers_english_championship_2017 = pd.read_csv('Transfers2017/english_championship_2017.csv')
transfers_english_premier_league_2017 = pd.read_csv('Transfers2017/english_premier_league_2017.csv')
transfers_french_ligue_1_2017 = pd.read_csv('Transfers2017/french_ligue_1_2017.csv')
transfers_german_bundesliga_1_2017 = pd.read_csv('Transfers2017/german_bundesliga_1_2017.csv')
transfers_italian_serie_a_2017 = pd.read_csv('Transfers2017/italian_serie_a_2017.csv')
transfers_portugese_liga_nos_2017 = pd.read_csv('Transfers2017/portugese_liga_nos_2017.csv')
transfers_spanish_primera_division_2017 = pd.read_csv('Transfers2017/spanish_primera_division_2017.csv')
all_transfers_2017 = pd.concat([transfers_eredivisie_2017, transfers_english_championship_2017, transfers_english_premier_league_2017,transfers_french_ligue_1_2017,transfers_german_bundesliga_1_2017,transfers_italian_serie_a_2017,transfers_portugese_liga_nos_2017,transfers_spanish_primera_division_2017]).sort_index().reset_index(drop=True)
#Dropping all NaN's in the fee_cleaned column
all_transfer_2017 = all_transfers_2017.dropna(subset = ["fee_cleaned"], inplace = True)
all_transfers_2017 = pd.concat([all_transfers_2017]).sort_index().reset_index(drop=True)
#Taking out all values of 0 in fee_cleaned as this are not real transfers (mostly loans of ended contracts)
for i in range(len(all_transfers_2017)):
    if all_transfers_2017['fee_cleaned'][i] <= 0.00:
        all_transfers_2017 = all_transfers_2017.drop(i)
all_transfers_2017 = pd.concat([all_transfers_2017]).sort_index().reset_index(drop=True)
for i in range(len(all_transfers_2017)):
    if all_transfers_2017['transfer_movement'][i] == 'out':
        all_transfers_2017 = all_transfers_2017.drop(i)
all_transfers_2017 = pd.concat([all_transfers_2017]).sort_index().reset_index(drop=True)

#2018
#Creating a dataframe with all transfers made in different competitions and merging them
transfers_eredivisie_2018 = pd.read_csv('Transfers2018/dutch_eredivisie_2018.csv')
transfers_english_championship_2018 = pd.read_csv('Transfers2018/english_championship_2018.csv')
transfers_english_premier_league_2018 = pd.read_csv('Transfers2018/english_premier_league_2018.csv')
transfers_french_ligue_1_2018 = pd.read_csv('Transfers2018/french_ligue_1_2018.csv')
transfers_german_bundesliga_1_2018 = pd.read_csv('Transfers2018/german_bundesliga_1_2018.csv')
transfers_italian_serie_a_2018 = pd.read_csv('Transfers2018/italian_serie_a_2018.csv')
transfers_portugese_liga_nos_2018 = pd.read_csv('Transfers2018/portugese_liga_nos_2018.csv')
transfers_spanish_primera_division_2018 = pd.read_csv('Transfers2018/spanish_primera_division_2018.csv')
all_transfers_2018 = pd.concat([transfers_eredivisie_2018, transfers_english_championship_2018, transfers_english_premier_league_2018,transfers_french_ligue_1_2018,transfers_german_bundesliga_1_2018,transfers_italian_serie_a_2018,transfers_portugese_liga_nos_2018,transfers_spanish_primera_division_2018]).sort_index().reset_index(drop=True)
#Dropping all NaN's in the fee_cleaned column
all_transfer_2018 = all_transfers_2018.dropna(subset = ["fee_cleaned"], inplace = True)
all_transfers_2018 = pd.concat([all_transfers_2018]).sort_index().reset_index(drop=True)
#Taking out all values of 0 in fee_cleaned as this are not real transfers (mostly loans of ended contracts)
for i in range(len(all_transfers_2018)):
    if all_transfers_2018['fee_cleaned'][i] <= 0.00:
        all_transfers_2018 = all_transfers_2018.drop(i)
all_transfers_2018 = pd.concat([all_transfers_2018]).sort_index().reset_index(drop=True)
for i in range(len(all_transfers_2018)):
    if all_transfers_2018['transfer_movement'][i] == 'out':
        all_transfers_2018 = all_transfers_2018.drop(i)
all_transfers_2018 = pd.concat([all_transfers_2018]).sort_index().reset_index(drop=True)

#2019
#Creating a dataframe with all transfers made in different competitions and merging them
transfers_eredivisie_2019 = pd.read_csv('Transfers2019/dutch_eredivisie_2019.csv')
transfers_english_championship_2019 = pd.read_csv('Transfers2019/english_championship_2019.csv')
transfers_english_premier_league_2019 = pd.read_csv('Transfers2019/english_premier_league_2019.csv')
transfers_french_ligue_1_2019 = pd.read_csv('Transfers2019/french_ligue_1_2019.csv')
transfers_german_bundesliga_1_2019 = pd.read_csv('Transfers2019/german_bundesliga_1_2019.csv')
transfers_italian_serie_a_2019 = pd.read_csv('Transfers2019/italian_serie_a_2019.csv')
transfers_portugese_liga_nos_2019 = pd.read_csv('Transfers2019/portugese_liga_nos_2019.csv')
transfers_spanish_primera_division_2019 = pd.read_csv('Transfers2019/spanish_primera_division_2019.csv')
all_transfers_2019 = pd.concat([transfers_eredivisie_2019, transfers_english_championship_2019, transfers_english_premier_league_2019,transfers_french_ligue_1_2019,transfers_german_bundesliga_1_2019,transfers_italian_serie_a_2019,transfers_portugese_liga_nos_2019,transfers_spanish_primera_division_2019]).sort_index().reset_index(drop=True)
#Dropping all NaN's in the fee_cleaned column
all_transfer_2019 = all_transfers_2019.dropna(subset = ["fee_cleaned"], inplace = True)
all_transfers_2019 = pd.concat([all_transfers_2019]).sort_index().reset_index(drop=True)
#Taking out all values of 0 in fee_cleaned as this are not real transfers (mostly loans of ended contracts)
for i in range(len(all_transfers_2019)):
    if all_transfers_2019['fee_cleaned'][i] <= 0.00:
        all_transfers_2019 = all_transfers_2019.drop(i)
all_transfers_2019 = pd.concat([all_transfers_2019]).sort_index().reset_index(drop=True)
for i in range(len(all_transfers_2019)):
    if all_transfers_2019['transfer_movement'][i] == 'out':
        all_transfers_2019 = all_transfers_2019.drop(i)
all_transfers_2019 = pd.concat([all_transfers_2019]).sort_index().reset_index(drop=True)

#2020
#Creating a dataframe with all transfers made in different competitions and merging them
transfers_eredivisie_2020 = pd.read_csv('Transfers2020/dutch_eredivisie_2020.csv')
transfers_english_championship_2020 = pd.read_csv('Transfers2020/english_championship_2020.csv')
transfers_english_premier_league_2020 = pd.read_csv('Transfers2020/english_premier_league_2020.csv')
transfers_french_ligue_1_2020 = pd.read_csv('Transfers2020/french_ligue_1_2020.csv')
transfers_german_bundesliga_1_2020 = pd.read_csv('Transfers2020/german_bundesliga_1_2020.csv')
transfers_italian_serie_a_2020 = pd.read_csv('Transfers2020/italian_serie_a_2020.csv')
transfers_portugese_liga_nos_2020 = pd.read_csv('Transfers2020/portugese_liga_nos_2020.csv')
transfers_spanish_primera_division_2020 = pd.read_csv('Transfers2020/spanish_primera_division_2020.csv')
all_transfers_2020 = pd.concat([transfers_eredivisie_2020, transfers_english_championship_2020, transfers_english_premier_league_2020,transfers_french_ligue_1_2020,transfers_german_bundesliga_1_2020,transfers_italian_serie_a_2020,transfers_portugese_liga_nos_2020,transfers_spanish_primera_division_2020]).sort_index().reset_index(drop=True)
#Dropping all NaN's in the fee_cleaned column
all_transfer_2020 = all_transfers_2020.dropna(subset = ["fee_cleaned"], inplace = True)
all_transfers_2020 = pd.concat([all_transfers_2020]).sort_index().reset_index(drop=True)
#Taking out all values of 0 in fee_cleaned as this are not real transfers (mostly loans of ended contracts)
for i in range(len(all_transfers_2020)):
    if all_transfers_2020['fee_cleaned'][i] <= 0.00:
        all_transfers_2020 = all_transfers_2020.drop(i)
all_transfers_2020 = pd.concat([all_transfers_2020]).sort_index().reset_index(drop=True)
for i in range(len(all_transfers_2020)):
    if all_transfers_2020['transfer_movement'][i] == 'out':
        all_transfers_2020 = all_transfers_2020.drop(i)
all_transfers_2020 = pd.concat([all_transfers_2020]).sort_index().reset_index(drop=True)

#2021
#Creating a dataframe with all transfers made in different competitions and merging them
transfers_eredivisie_2021 = pd.read_csv('Transfers2021/dutch_eredivisie_2021.csv')
transfers_english_championship_2021 = pd.read_csv('Transfers2021/english_championship_2021.csv')
transfers_english_premier_league_2021 = pd.read_csv('Transfers2021/english_premier_league_2021.csv')
transfers_french_ligue_1_2021 = pd.read_csv('Transfers2021/french_ligue_1_2021.csv')
transfers_german_bundesliga_1_2021 = pd.read_csv('Transfers2021/german_bundesliga_1_2021.csv')
transfers_italian_serie_a_2021 = pd.read_csv('Transfers2021/italian_serie_a_2021.csv')
transfers_portugese_liga_nos_2021 = pd.read_csv('Transfers2021/portugese_liga_nos_2021.csv')
transfers_spanish_primera_division_2021 = pd.read_csv('Transfers2021/spanish_primera_division_2021.csv')
all_transfers_2021 = pd.concat([transfers_eredivisie_2021, transfers_english_championship_2021, transfers_english_premier_league_2021,transfers_french_ligue_1_2021,transfers_german_bundesliga_1_2021,transfers_italian_serie_a_2021,transfers_portugese_liga_nos_2021,transfers_spanish_primera_division_2021]).sort_index().reset_index(drop=True)
#Dropping all NaN's in the fee_cleaned column
all_transfer_2021 = all_transfers_2021.dropna(subset = ["fee_cleaned"], inplace = True)
all_transfers_2021 = pd.concat([all_transfers_2021]).sort_index().reset_index(drop=True)
#Taking out all values of 0 in fee_cleaned as this are not real transfers (mostly loans of ended contracts)
for i in range(len(all_transfers_2021)):
    if all_transfers_2021['fee_cleaned'][i] <= 0.00:
        all_transfers_2021 = all_transfers_2021.drop(i)
all_transfers_2021 = pd.concat([all_transfers_2021]).sort_index().reset_index(drop=True)
for i in range(len(all_transfers_2021)):
    if all_transfers_2021['transfer_movement'][i] == 'out':
        all_transfers_2021 = all_transfers_2021.drop(i)
all_transfers_2021 = pd.concat([all_transfers_2021]).sort_index().reset_index(drop=True)

#Merging them all together
all_transfers = pd.concat([all_transfers_2015, all_transfers_2016, all_transfers_2017, all_transfers_2018, all_transfers_2019, all_transfers_2020, all_transfers_2021]).sort_index().reset_index(drop=True)
for i in range(len(all_transfers)):
    if 'Loan' in all_transfers['fee'][i]:
        all_transfers = all_transfers.drop(i)
all_transfers = pd.concat([all_transfers]).sort_index().reset_index(drop=True)
all_transfers
# Out:
#            club_name       player_name   age            position  \
# 0      PSV Eindhoven    Gastón Pereiro  20.0  Attacking Midfield
# 1      Bayern Munich   Lucas Hernández  23.0         Centre-Back
# 2     Ajax Amsterdam    Mohamed Daramy  19.0         Left Winger
# 3          Amiens SC     Saman Ghoddos  24.0  Attacking Midfield
# 4         Arsenal FC     Thomas Partey  27.0  Defensive Midfield
# ...              ...               ...   ...                 ...
# 4565     US Sassuolo      Andrea Cisco  19.0         Left Winger
# 4566       SPAL 2013     Mattia Vitale  20.0    Central Midfield
# 4567       SPAL 2013      Everton Luiz  29.0  Defensive Midfield
# 4568       SPAL 2013     Thiago Cionek  31.0         Centre-Back
# 4569       Torino FC  Vitalie Damascan  18.0      Centre-Forward
#
#      club_involved_name      fee transfer_movement transfer_period  \
# 0              Nacional   £6.30m                in          Summer
# ...

# %%
all_transfers_2015['player_url'] = 0
all_transfers_2016['player_url'] = 0
all_transfers_2017['player_url'] = 0
all_transfers_2018['player_url'] = 0
all_transfers_2019['player_url'] = 0
all_transfers_2020['player_url'] = 0
all_transfers_2021['player_url'] = 0

# %%
#example of alternative
all_transfers_2015['id-name'] = ''
for i in range(len(all_transfers_2015)):
    for k in range(len(all_transfers_2015['player_name'][i].split())):
        all_transfers_2015['id-name'][i] += all_transfers_2015['player_name'][i].split()[k].lower() + '-'
    if len(all_transfers_2015['id-name'][i]) < 10:
        all_transfers_2015['id-name'][i] = ''
    all_transfers_2015['id-name'][i] = all_transfers_2015['id-name'][i][:-1]
# Out:
# <ipython-input-3-7a1c9d9ce4ba>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   all_transfers_2015['id-name'][i] += all_transfers_2015['player_name'][i].split()[k].lower() + '-'
# <ipython-input-3-7a1c9d9ce4ba>:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   all_transfers_2015['id-name'][i] = all_transfers_2015['id-name'][i][:-1]
# <ipython-input-3-7a1c9d9ce4ba>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %%
#Adding an url to the players
players_2015_2016 = pd.read_csv('All fifa data/players_16.csv')
players_2016_2017 = pd.read_csv('All fifa data/players_17.csv')
players_2017_2018 = pd.read_csv('All fifa data/players_18.csv')
players_2018_2019 = pd.read_csv('All fifa data/players_19.csv')
players_2019_2020 = pd.read_csv('All fifa data/players_20.csv')
players_2020_2021 = pd.read_csv('All fifa data/players_21.csv')
players_2021_2022 = pd.read_csv('All fifa data/players_22.csv')
all_transfers_2015['id-name'] = ''
for i in range(len(all_transfers_2015)):
    for k in range(len(all_transfers_2015['player_name'][i].split())):
        all_transfers_2015['id-name'][i] += all_transfers_2015['player_name'][i].split()[k].lower() + '-'
    all_transfers_2015['id-name'][i] = all_transfers_2015['id-name'][i][:-1]
def adding_url2015():
    for i in range(len(all_transfers_2015)):
        for j in range(len(players_2015_2016)):
            if all_transfers_2015['player_name'][i] in players_2015_2016['long_name'][j]:
                all_transfers_2015['player_url'][i] = players_2015_2016['player_url'][j]
            elif all_transfers_2015['player_name'][i] in players_2015_2016['short_name'][j]:
                all_transfers_2015['player_url'][i] = players_2015_2016['player_url'][j]
            elif all_transfers_2015['id-name'][i] in players_2015_2016['player_url'][j]:
                all_transfers_2015['player_url'][i] = players_2015_2016['player_url'][j]
            else:
                continue
adding_url2015()
all_transfers_2016['id-name'] = ''
for i in range(len(all_transfers_2016)):
    for k in range(len(all_transfers_2016['player_name'][i].split())):
        all_transfers_2016['id-name'][i] += all_transfers_2016['player_name'][i].split()[k].lower() + '-'
    all_transfers_2016['id-name'][i] = all_transfers_2016['id-name'][i][:-1]
def adding_url2016():
    for i in range(len(all_transfers_2016)):
        for j in range(len(players_2016_2017)):
            if all_transfers_2016['player_name'][i] in players_2016_2017['long_name'][j]:
                all_transfers_2016['player_url'][i] = players_2016_2017['player_url'][j]
            elif all_transfers_2016['player_name'][i] in players_2016_2017['short_name'][j]:
                all_transfers_2016['player_url'][i] = players_2016_2017['player_url'][j]
            elif all_transfers_2016['id-name'][i] in players_2016_2017['player_url'][j]:
                all_transfers_2016['player_url'][i] = players_2016_2017['player_url'][j]
            else:
                continue
adding_url2016()
all_transfers_2017['id-name'] = ''
for i in range(len(all_transfers_2017)):
    for k in range(len(all_transfers_2017['player_name'][i].split())):
        all_transfers_2017['id-name'][i] += all_transfers_2017['player_name'][i].split()[k].lower() + '-'
    all_transfers_2017['id-name'][i] = all_transfers_2017['id-name'][i][:-1]
def adding_url2017():
    for i in range(len(all_transfers_2017)):
        for j in range(len(players_2017_2018)):
            if all_transfers_2017['player_name'][i] in players_2017_2018['long_name'][j]:
                all_transfers_2017['player_url'][i] = players_2017_2018['player_url'][j]
            elif all_transfers_2017['player_name'][i] in players_2017_2018['short_name'][j]:
                all_transfers_2017['player_url'][i] = players_2017_2018['player_url'][j]
            elif all_transfers_2017['id-name'][i] in players_2017_2018['player_url'][j]:
                all_transfers_2017['player_url'][i] = players_2017_2018['player_url'][j]
            else:
                continue
adding_url2017()
all_transfers_2018['id-name'] = ''
for i in range(len(all_transfers_2018)):
    for k in range(len(all_transfers_2018['player_name'][i].split())):
        all_transfers_2018['id-name'][i] += all_transfers_2018['player_name'][i].split()[k].lower() + '-'
    all_transfers_2018['id-name'][i] = all_transfers_2018['id-name'][i][:-1]
def adding_url2018():
    for i in range(len(all_transfers_2018)):
        for j in range(len(players_2018_2019)):
            if all_transfers_2018['player_name'][i] in players_2018_2019['long_name'][j]:
                all_transfers_2018['player_url'][i] = players_2018_2019['player_url'][j]
            elif all_transfers_2018['player_name'][i] in players_2018_2019['short_name'][j]:
                all_transfers_2018['player_url'][i] = players_2018_2019['player_url'][j]
            elif all_transfers_2018['id-name'][i] in players_2018_2019['player_url'][j]:
                all_transfers_2018['player_url'][i] = players_2018_2019['player_url'][j]
            else:
                continue
adding_url2018()
all_transfers_2019['id-name'] = ''
for i in range(len(all_transfers_2019)):
    for k in range(len(all_transfers_2019['player_name'][i].split())):
        all_transfers_2019['id-name'][i] += all_transfers_2019['player_name'][i].split()[k].lower() + '-'
    all_transfers_2019['id-name'][i] = all_transfers_2019['id-name'][i][:-1]
def adding_url2019():
    for i in range(len(all_transfers_2019)):
        for j in range(len(players_2019_2020)):
            if all_transfers_2019['player_name'][i] in players_2019_2020['long_name'][j]:
                all_transfers_2019['player_url'][i] = players_2019_2020['player_url'][j]
            elif all_transfers_2019['player_name'][i] in players_2019_2020['short_name'][j]:
                all_transfers_2019['player_url'][i] = players_2019_2020['player_url'][j]
            elif all_transfers_2019['id-name'][i] in players_2019_2020['player_url'][j]:
                all_transfers_2019['player_url'][i] = players_2019_2020['player_url'][j]
            else:
                continue
adding_url2019()
all_transfers_2020['id-name'] = ''
for i in range(len(all_transfers_2020)):
    for k in range(len(all_transfers_2020['player_name'][i].split())):
        all_transfers_2020['id-name'][i] += all_transfers_2020['player_name'][i].split()[k].lower() + '-'
    all_transfers_2020['id-name'][i] = all_transfers_2020['id-name'][i][:-1]
def adding_url2020():
    for i in range(len(all_transfers_2020)):
        for j in range(len(players_2020_2021)):
            if all_transfers_2020['player_name'][i] in players_2020_2021['long_name'][j]:
                all_transfers_2020['player_url'][i] = players_2020_2021['player_url'][j]
            elif all_transfers_2020['player_name'][i] in players_2020_2021['short_name'][j]:
                all_transfers_2020['player_url'][i] = players_2020_2021['player_url'][j]
            elif all_transfers_2020['id-name'][i] in players_2020_2021['player_url'][j]:
                all_transfers_2020['player_url'][i] = players_2020_2021['player_url'][j]
            else:
                continue
adding_url2020()
all_transfers_2021['id-name'] = ''
for i in range(len(all_transfers_2021)):
    for k in range(len(all_transfers_2021['player_name'][i].split())):
        all_transfers_2021['id-name'][i] += all_transfers_2021['player_name'][i].split()[k].lower() + '-'
    all_transfers_2021['id-name'][i] = all_transfers_2021['id-name'][i][:-1]
def adding_url2021():
    for i in range(len(all_transfers_2021)):
        for j in range(len(players_2021_2022)):
            if all_transfers_2021['player_name'][i] in players_2021_2022['long_name'][j]:
                all_transfers_2021['player_url'][i] = players_2021_2022['player_url'][j]
            elif all_transfers_2021['player_name'][i] in players_2021_2022['short_name'][j]:
                all_transfers_2021['player_url'][i] = players_2021_2022['player_url'][j]
            elif all_transfers_2021['id-name'][i] in players_2021_2022['player_url'][j]:
                all_transfers_2021['player_url'][i] = players_2021_2022['player_url'][j]
            else:
                continue
adding_url2021()
# Out:
# C:\Users\gijsl\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3071: DtypeWarning: Columns (25,108) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
# <ipython-input-4-c4ecd7270187>:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   all_transfers_2015['id-name'][i] += all_transfers_2015['player_name'][i].split()[k].lower() + '-'
# <ipython-input-4-c4ecd7270187>:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   all_transfers_2015['id-name'][i] = all_transfers_2015['id-name'][i][:-1]
# ...

# %%
all_transfers = pd.concat([all_transfers_2015, all_transfers_2016, all_transfers_2017, all_transfers_2018, all_transfers_2019, all_transfers_2020, all_transfers_2021]).sort_index().reset_index(drop=True)

# %%
for i in range(len(all_transfers)):
    if 'Loan' in all_transfers['fee'][i]:
        all_transfers = all_transfers.drop(i)
all_transfers = pd.concat([all_transfers]).sort_index().reset_index(drop=True)
all_transfers
# Out:
#            club_name       player_name   age            position  \
# 0      PSV Eindhoven    Gastón Pereiro  20.0  Attacking Midfield
# 1      Bayern Munich   Lucas Hernández  23.0         Centre-Back
# 2     Ajax Amsterdam    Mohamed Daramy  19.0         Left Winger
# 3          Amiens SC     Saman Ghoddos  24.0  Attacking Midfield
# 4         Arsenal FC     Thomas Partey  27.0  Defensive Midfield
# ...              ...               ...   ...                 ...
# 4565     US Sassuolo      Andrea Cisco  19.0         Left Winger
# 4566       SPAL 2013     Mattia Vitale  20.0    Central Midfield
# 4567       SPAL 2013      Everton Luiz  29.0  Defensive Midfield
# 4568       SPAL 2013     Thiago Cionek  31.0         Centre-Back
# 4569       Torino FC  Vitalie Damascan  18.0      Centre-Forward
#
#      club_involved_name      fee transfer_movement transfer_period  \
# 0              Nacional   £6.30m                in          Summer
# ...

# %%
all_transfers.to_csv('transfer-data-test3.csv')
#Met oude preprocessing, bestand heet nu transfer-data-test2-goed.csv, omdat transfer-data-test2.csv overschreven wordt

# %%
#Making one fifa database
players_2015_2016 = pd.read_csv('All fifa data/players_16.csv')
players_2016_2017 = pd.read_csv('All fifa data/players_17.csv')
players_2017_2018 = pd.read_csv('All fifa data/players_18.csv')
players_2018_2019 = pd.read_csv('All fifa data/players_19.csv')
players_2019_2020 = pd.read_csv('All fifa data/players_20.csv')
players_2020_2021 = pd.read_csv('All fifa data/players_21.csv')
players_2021_2022 = pd.read_csv('All fifa data/players_22.csv')
all_fifa_data = pd.concat([players_2015_2016, players_2016_2017, players_2017_2018, players_2018_2019, players_2019_2020, players_2020_2021, players_2021_2022]).sort_index().reset_index(drop=True)
#all_fifa_data.to_csv('fifa-data-test2.csv')
# Out:
# C:\Users\gijsl\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3071: DtypeWarning: Columns (25,108) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

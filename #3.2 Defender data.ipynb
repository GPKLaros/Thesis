# %%
import pandas as pd
import numpy as np
##Loading the complete fifa database
complete_data = pd.read_csv('complete_data_test.csv', sep=',')
for i in range(len(complete_data)):
    if complete_data['year'][i] == 2021:
        complete_data['contract_valid_until'][i] = complete_data['club_contract_valid_until'][i]
# Out:
# <ipython-input-1-da66d0b2843e>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   complete_data['contract_valid_until'][i] = complete_data['club_contract_valid_until'][i]

# %%
#Removing variables that are unnecessary and renaming columns.
complete_data.drop(['Unnamed: 0_x', 'Unnamed: 0', 'player_name', 'fee', 'transfer_movement', 'club_name_y', 'league_name_y', 'league_rank', 'season', 'player_url', 'id-name', 'Unnamed: 0_y', 'sofifa_id', 'short_name', 'long_name', 'age_y', 'dob', 'player_positions', 'work_rate', 'body_type', 'real_face', 'player_tags', 'player_traits', 'team_position', 'team_jersey_number', 'loaned_from', 'joined', 'nation_position', 'nation_jersey_number', 'gk_diving', 'gk_handling', 'gk_kicking', 'gk_reflexes', 'gk_speed', 'gk_positioning', 'mentality_composure', 'defending_marking', 'value_eur', 'wage_eur'], axis = 1, inplace = True)
complete_data.rename(columns = {'club_name_x':'buying_club', 'age_x':'age','club_involved_name':'selling_club', 'league_name_x':'buying_league'}, inplace = True)
complete_data.drop(complete_data.iloc[:, 56:], inplace = True, axis = 1)

# %%
#Turning position into position_group
defenders = ['Centre-Back', 'Left-Back', 'Right-Back']
midfielders = ['Attacking Midfield', 'Defensive Midfield', 'Central Midfield', 'Right Midfield', 'Left Midfield']
attackers = ['Centre-Forward', 'Left Winger', 'Right Winger', 'Second Striker']
complete_data['position_group'] = 0
for i in range(len(complete_data)):
    if complete_data['position'][i] in defenders:
        complete_data['position_group'][i] = 'Defender'
    elif complete_data['position'][i] in midfielders:
        complete_data['position_group'][i] = 'Midfielder'
    elif complete_data['position'][i] in attackers:
        complete_data['position_group'][i] = 'Attacker'
complete_data = complete_data[complete_data["position_group"].str.contains('Defender') == True]
# Out:
# <ipython-input-3-d719ff296462>:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   complete_data['position_group'][i] = 'Defender'
# C:\Users\gijsl\anaconda3\lib\site-packages\pandas\core\indexing.py:1637: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)
# <ipython-input-3-d719ff296462>:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   complete_data['position_group'][i] = 'Attacker'
# <ipython-input-3-d719ff296462>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   complete_data['position_group'][i] = 'Midfielder'

# %%
#Variables changed to categoric variables
complete_data['buying_club'] = pd.Categorical(complete_data['buying_club'])
complete_data['selling_club'] = pd.Categorical(complete_data['selling_club'])
complete_data['transfer_period'] = pd.Categorical(complete_data['transfer_period'])
complete_data['buying_league'] = pd.Categorical(complete_data['buying_league'])
complete_data['nationality'] = pd.Categorical(complete_data['nationality'])
complete_data['international_reputation'] = pd.Categorical(complete_data['international_reputation'])
complete_data['position'] = pd.Categorical(complete_data['position'])
complete_data['weak_foot'] = pd.Categorical(complete_data['weak_foot'])
complete_data['skill_moves'] = pd.Categorical(complete_data['skill_moves'])
complete_data['international_reputation'] = pd.Categorical(complete_data['international_reputation'])
complete_data['position_group'] = pd.Categorical(complete_data['position_group'])

# %%
#Taking all goalkeepers out of the data
data_without_gk = complete_data[complete_data["position"].str.contains('Goalkeeper') == False]
data_with_gk = complete_data[complete_data["position"].str.contains('Goalkeeper') == True]
data_without_gk = data_without_gk.reset_index(drop=True)
data_with_gk = data_with_gk.reset_index(drop=True)
# Out:
#           buying_club   age     position     selling_club transfer_period  \
# 0       Bayern Munich  23.0  Centre-Back  Atlético Madrid          Summer
# 1     Manchester City  25.0   Right-Back         Juventus          Summer
# 2       Bayern Munich  22.0  Centre-Back       RB Leipzig          Summer
# 3            FC Porto  20.0  Centre-Back        São Paulo          Summer
# 4         Inter Milan  21.0  Centre-Back   Standard Liège          Summer
# ...               ...   ...          ...              ...             ...
# 1237     Ipswich Town  19.0   Right-Back      Limerick FC          Winter
# 1238         SS Lazio  30.0  Centre-Back    Hellas Verona          Winter
# 1239     UC Sampdoria  26.0    Left-Back            Inter          Winter
# 1240      US Sassuolo  20.0   Right-Back         Juventus          Winter
# 1241        SPAL 2013  31.0  Centre-Back       US Palermo          Winter
#
#       fee_cleaned   buying_league  year  height_cm  weight_kg  ...  \
# 0          72.000    1 Bundesliga  2019        182         76  ...
# 1          58.500  Premier League  2019        182         74  ...
# 2          38.250    1 Bundesliga  2021        186         90  ...
# 3           6.300        Liga Nos  2018        186         79  ...
# 4          14.400         Serie A  2021        187         78  ...
# ...           ...             ...   ...        ...        ...  ...
# 1237        0.072    Championship  2017        175         68  ...
# 1238        0.540         Serie A  2017        180         78  ...
# 1239        4.950         Serie A  2017        177         75  ...
# 1240        6.300         Serie A  2017        183         70  ...
# 1241        0.135         Serie A  2017        183         80  ...
#
#      mentality_positioning  mentality_vision  mentality_penalties  \
# 0                       62                63                   42
# 1                       78                78                   46
# 2                       47                58                   39
# 3                       59                59                   60
# 4                       47                59                   62
# ...                    ...               ...                  ...
# 1237                    50                46                   39
# 1238                    50                58                   50
# 1239                    70                65                   46
# 1240                    64                58                   30
# 1241                    30                36                   39
#
#      defending_standing_tackle defending_sliding_tackle goalkeeping_diving  \
# 0                           84                       86                 10
# 1                           80                       80                  6
# 2                           84                       90                  6
# 3                           73                       76                 11
# 4                           76                       77                 11
# ...                        ...                      ...                ...
# 1237                        50                       49                  7
# 1238                        78                       77                  2
# 1239                        64                       65                 15
# 1240                        74                       73                 12
# 1241                        73                       72                  6
#
#      goalkeeping_handling  goalkeeping_kicking  goalkeeping_positioning  \
# 0                       7                    8                       14
# 1                       9                   15                       14
# 2                       7                    8                       15
# 3                       8                   15                       12
# 4                       9                    9                        9
# ...                   ...                  ...                      ...
# 1237                   13                    9                        8
# 1238                    3                    4                        2
# 1239                    8                   13                       10
# 1240                   12                    5                        9
# 1241                    8                    8                        9
#
#       position_group
# 0           Defender
# 1           Defender
# 2           Defender
# 3           Defender
# 4           Defender
# ...              ...
# 1237        Defender
# 1238        Defender
# 1239        Defender
# 1240        Defender
# 1241        Defender
#
# [1242 rows x 57 columns]

# %%
#Creating the dummy variables
position_group_dummy = pd.get_dummies(data_without_gk['position_group'], prefix='position')
#2 in iloc because otherwise it would take 0 (for goalkeepers) as the base category, because of the 2 it is attacker
position_group_dummy = position_group_dummy.iloc[: , 2:]
buying_league_dummy = pd.get_dummies(data_without_gk['buying_league'], prefix='buying_league')
buying_league_dummy = buying_league_dummy.iloc[: , 1:]
nationality_dummy = pd.get_dummies(data_without_gk['nationality'], prefix='nationality')
nationality_dummy = nationality_dummy.iloc[: , 1:]
preferred_foot_dummy = pd.get_dummies(data_without_gk['preferred_foot'], prefix='preferred_foot')
preferred_foot_dummy = preferred_foot_dummy.iloc[: , 1:]
transfer_period_dummy = pd.get_dummies(data_without_gk['transfer_period'], prefix='transfer_period')
transfer_period_dummy = transfer_period_dummy.iloc[: , 1:]

#Dropping the initial values of the new dummies and the goalkeeper skills
temp = data_without_gk.drop(['position', 'release_clause_eur', 'buying_league', 'selling_club', 'buying_club', 'nationality', 'preferred_foot', 'transfer_period', 'position_group'], axis = 1)
model_data = pd.concat([temp, position_group_dummy, buying_league_dummy, nationality_dummy, preferred_foot_dummy, transfer_period_dummy], axis = 1)

# %%
#Number of rows with NA
model_data.isnull().any(axis=1).sum()
# Out:
# 11

# %%
#Number of empty cells per column
for col in model_data:
    print(col, ':', (model_data[col].isna().sum()/len(model_data))*100)
# Out:
# age : 0.0
# fee_cleaned : 0.0
# year : 0.0
# height_cm : 0.0
# weight_kg : 0.0
# overall : 0.0
# potential : 0.0
# international_reputation : 0.0
# weak_foot : 0.0
# skill_moves : 0.0
# contract_valid_until : 0.0
# pace : 0.8856682769726247
# shooting : 0.8856682769726247
# passing : 0.8856682769726247
# dribbling : 0.8856682769726247
# defending : 0.8856682769726247
# physic : 0.8856682769726247
# attacking_crossing : 0.0
# attacking_finishing : 0.0
# attacking_heading_accuracy : 0.0
# attacking_short_passing : 0.0
# attacking_volleys : 0.0
# skill_dribbling : 0.0
# skill_curve : 0.0
# skill_fk_accuracy : 0.0
# skill_long_passing : 0.0
# skill_ball_control : 0.0
# movement_acceleration : 0.0
# movement_sprint_speed : 0.0
# movement_agility : 0.0
# movement_reactions : 0.0
# movement_balance : 0.0
# power_shot_power : 0.0
# power_jumping : 0.0
# power_stamina : 0.0
# power_strength : 0.0
# power_long_shots : 0.0
# mentality_aggression : 0.0
# mentality_interceptions : 0.0
# mentality_positioning : 0.0
# mentality_vision : 0.0
# mentality_penalties : 0.0
# defending_standing_tackle : 0.0
# defending_sliding_tackle : 0.0
# goalkeeping_diving : 0.0
# goalkeeping_handling : 0.0
# goalkeeping_kicking : 0.0
# goalkeeping_positioning : 0.0
# buying_league_Championship : 0.0
# buying_league_Eredivisie : 0.0
# buying_league_Liga Nos : 0.0
# buying_league_Ligue 1 : 0.0
# buying_league_Premier League : 0.0
# buying_league_Primera Division : 0.0
# buying_league_Serie A : 0.0
# nationality_Algeria : 0.0
# nationality_Angola : 0.0
# nationality_Argentina : 0.0
# nationality_Australia : 0.0
# nationality_Austria : 0.0
# nationality_Belgium : 0.0
# nationality_Bosnia Herzegovina : 0.0
# nationality_Brazil : 0.0
# nationality_Bulgaria : 0.0
# nationality_Burkina Faso : 0.0
# nationality_Cameroon : 0.0
# nationality_Canada : 0.0
# nationality_Central African Republic : 0.0
# nationality_Chile : 0.0
# nationality_China PR : 0.0
# nationality_Colombia : 0.0
# nationality_Comoros : 0.0
# nationality_Congo : 0.0
# nationality_Costa Rica : 0.0
# nationality_Croatia : 0.0
# nationality_Curacao : 0.0
# nationality_Cyprus : 0.0
# nationality_Czech Republic : 0.0
# nationality_Côte d'Ivoire : 0.0
# nationality_DR Congo : 0.0
# nationality_Denmark : 0.0
# nationality_Egypt : 0.0
# nationality_England : 0.0
# nationality_Equatorial Guinea : 0.0
# nationality_Estonia : 0.0
# nationality_Finland : 0.0
# nationality_France : 0.0
# nationality_Gabon : 0.0
# nationality_Gambia : 0.0
# nationality_Germany : 0.0
# nationality_Ghana : 0.0
# nationality_Greece : 0.0
# nationality_Hungary : 0.0
# nationality_Iceland : 0.0
# nationality_Iraq : 0.0
# nationality_Israel : 0.0
# nationality_Italy : 0.0
# nationality_Ivory Coast : 0.0
# nationality_Jamaica : 0.0
# nationality_Japan : 0.0
# nationality_Kosovo : 0.0
# nationality_Mali : 0.0
# nationality_Mexico : 0.0
# nationality_Montenegro : 0.0
# nationality_Morocco : 0.0
# nationality_Netherlands : 0.0
# nationality_New Caledonia : 0.0
# nationality_New Zealand : 0.0
# nationality_Nigeria : 0.0
# nationality_North Macedonia : 0.0
# nationality_Northern Ireland : 0.0
# nationality_Norway : 0.0
# nationality_Paraguay : 0.0
# nationality_Peru : 0.0
# nationality_Poland : 0.0
# nationality_Portugal : 0.0
# nationality_Republic of Ireland : 0.0
# nationality_Romania : 0.0
# nationality_Russia : 0.0
# nationality_Scotland : 0.0
# nationality_Senegal : 0.0
# nationality_Serbia : 0.0
# nationality_Slovakia : 0.0
# nationality_Slovenia : 0.0
# nationality_Spain : 0.0
# nationality_Suriname : 0.0
# nationality_Sweden : 0.0
# nationality_Switzerland : 0.0
# nationality_Togo : 0.0
# nationality_Tunisia : 0.0
# nationality_Turkey : 0.0
# nationality_Uganda : 0.0
# nationality_Ukraine : 0.0
# nationality_United States : 0.0
# nationality_Uruguay : 0.0
# nationality_Venezuela : 0.0
# nationality_Wales : 0.0
# preferred_foot_Right : 0.0
# transfer_period_Winter : 0.0

# %%
#Dropping the rows with an empty value
model_data = model_data.dropna()
model_data = model_data.reset_index(drop=True)
model_data.to_csv('defender_data.csv', index = False)
model_data
# Out:
#        age  fee_cleaned  year  height_cm  weight_kg  overall  potential  \
# 0     23.0       72.000  2019        182         76       84         89
# 1     25.0       58.500  2019        182         74       84         89
# 2     22.0       38.250  2021        186         90       82         90
# 3     20.0        6.300  2018        186         79       75         86
# 4     21.0       14.400  2021        187         78       74         82
# ...    ...          ...   ...        ...        ...      ...        ...
# 1226  19.0        0.072  2017        175         68       52         62
# 1227  30.0        0.540  2017        180         78       77         77
# 1228  26.0        4.950  2017        177         75       73         75
# 1229  20.0        6.300  2017        183         70       74         80
# 1230  31.0        0.135  2017        183         80       71         71
#
#      international_reputation weak_foot skill_moves  ...  nationality_Tunisia  \
# 0                           3         3           2  ...                    0
# 1                           2         3           4  ...                    0
# 2                           2         3           2  ...                    0
# 3                           1         2           2  ...                    0
# 4                           1         3           2  ...                    0
# ...                       ...       ...         ...  ...                  ...
# 1226                        1         2           2  ...                    0
# 1227                        2         3           2  ...                    0
# 1228                        1         2           4  ...                    0
# 1229                        1         3           2  ...                    0
# 1230                        1         3           2  ...                    0
#
#       nationality_Turkey  nationality_Uganda  nationality_Ukraine  \
# 0                      0                   0                    0
# 1                      0                   0                    0
# 2                      0                   0                    0
# 3                      0                   0                    0
# 4                      0                   0                    0
# ...                  ...                 ...                  ...
# 1226                   0                   0                    0
# 1227                   0                   0                    0
# 1228                   0                   0                    0
# 1229                   0                   0                    0
# 1230                   0                   0                    0
#
#       nationality_United States  nationality_Uruguay  nationality_Venezuela  \
# 0                             0                    0                      0
# 1                             0                    0                      0
# 2                             0                    0                      0
# 3                             0                    0                      0
# 4                             0                    0                      0
# ...                         ...                  ...                    ...
# 1226                          0                    0                      0
# 1227                          0                    1                      0
# 1228                          0                    0                      0
# 1229                          0                    0                      0
# 1230                          0                    0                      0
#
#       nationality_Wales  preferred_foot_Right  transfer_period_Winter
# 0                     0                     0                       0
# 1                     0                     1                       0
# 2                     0                     1                       0
# 3                     0                     1                       0
# 4                     0                     1                       0
# ...                 ...                   ...                     ...
# 1226                  0                     1                       1
# 1227                  0                     1                       1
# 1228                  0                     0                       1
# 1229                  0                     1                       1
# 1230                  0                     1                       1
#
# [1231 rows x 139 columns]
